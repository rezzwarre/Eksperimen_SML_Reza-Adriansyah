# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset dapat diperoleh dari berbagai sumber, seperti public repositories (*Kaggle*, *UCI ML Repository*, *Open Data*) atau data primer yang Anda kumpulkan sendiri.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import pandas as pd
import os
import zipfile
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %% [markdown]
# ### 3.1 Download Dataset dari Kaggle

# %%
# # Download dataset dari Kaggle
# !kaggle datasets download -d jacopoferretti/iris-2-0-modern-flower-morphometrics-200k
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/jacopoferretti/iris-2-0-modern-flower-morphometrics-200k
# License(s): CC0-1.0
# iris-2-0-modern-flower-morphometrics-200k.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ### 3.2 Ekstraksi File Dataset

# %%
# # Ekstrak file zip dataset
# with zipfile.ZipFile("iris-2-0-modern-flower-morphometrics-200k.zip", "r") as zip_ref:
#     zip_ref.extractall(".")

# %% [markdown]
# ### 3.3 Membaca Data ke DataFrame

# %%
df = pd.read_csv('../namadataset_raw/extended_flower_morphometrics.csv')

# %% [markdown]
# ### 4.1 Menampilkan Data Teratas

# %%
df.head(5)
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0         4.317614        3.028292         6.092543        3.166156
# 1         5.531122        3.887679         5.497682        2.374855
# 2         5.908407        2.576321         6.264473        1.785481
# 3         6.855284        2.764075         4.606390        1.175031
# 4         5.412124        3.691987         1.800383        0.221225
#
#    stem_thickness_mm  petal_density_pct  chlorophyll_index  native_altitude_m  \
# 0           5.063025          63.558150          55.913100         886.568622
# 1           4.656235          52.368783          26.383116         247.206553
# 2           5.893707          36.056153          61.562376        1197.921681
# 3           4.854951          55.623467          38.671083         940.401196
# 4           2.528513          60.218904          34.674831         679.473136
#
#            species
# 0             Rose
# 1  Iris Versicolor
# 2           Orchid
# ...

# %% [markdown]
# ### 4.2 Informasi Struktur Data dan Statistik Deskriptif

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   sepal_length_cm    200000 non-null  float64
#  1   sepal_width_cm     200000 non-null  float64
#  2   petal_length_cm    200000 non-null  float64
#  3   petal_width_cm     200000 non-null  float64
#  4   stem_thickness_mm  200000 non-null  float64
#  5   petal_density_pct  200000 non-null  float64
#  6   chlorophyll_index  200000 non-null  float64
#  7   native_altitude_m  200000 non-null  float64
#  8   species            200000 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# count    200000.000000   200000.000000    200000.000000   200000.000000
# mean          6.494801        3.701722         5.660341        2.339627
# std           2.389844        1.219015         3.769632        1.761005
# min           1.314396       -0.681257        -0.040491       -1.097662
# 25%           4.976431        2.955377         3.371251        1.137561
# 50%           5.732968        3.406310         4.901882        2.118828
# 75%           6.973427        4.003575         6.466747        3.107515
# max          18.797057       11.130567        24.222782       10.444469
#
#        stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# count      200000.000000      200000.000000      200000.000000
# mean            6.756894          53.202820          45.769422
# std             4.301134          13.891707          10.579623
# min            -1.357669          -0.531327           2.766288
# ...

# %% [markdown]
# ### 4.3 Pengecekan Missing Values dan Duplikasi

# %%
df.isnull().sum()
# Out:
# sepal_length_cm      0
# sepal_width_cm       0
# petal_length_cm      0
# petal_width_cm       0
# stem_thickness_mm    0
# petal_density_pct    0
# chlorophyll_index    0
# native_altitude_m    0
# species              0
# dtype: int64

# %%
df
# Out:
#         sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              4.317614        3.028292         6.092543        3.166156
# 1              5.531122        3.887679         5.497682        2.374855
# 2              5.908407        2.576321         6.264473        1.785481
# 3              6.855284        2.764075         4.606390        1.175031
# 4              5.412124        3.691987         1.800383        0.221225
# ...                 ...             ...              ...             ...
# 199995         4.310318        3.203669         4.608296        3.181966
# 199996         5.441338        2.540579         3.065710        3.081896
# 199997         7.634411        2.717171         5.527709        0.544835
# 199998         5.840849        1.975244         8.855018        2.062708
# 199999         6.177141        3.201139         4.291363        2.253710
#
#         stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# ...

# %%
# Mengecek data terduplikasi menggunakan duplicated().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 4.4 Visualisasi Distribusi Fitur Numerik

# %%
# Menampilkan histogram untuk semua kolom numerik
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols].hist(bins=15, figsize=(15,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.5 Analisis Korelasi Antar Fitur

# %%
# Menampilkan korelasi antar fitur
plt.figure(figsize=(26,16))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Antar Fitur")
plt.show()

# %% [markdown]
# ### 4.6 Visualisasi Distribusi Target (Species)

# %%
# 1. Visualisasi Kolom Numerik (float64) menggunakan Histogram
numeric_cols = df.select_dtypes(include=['float64']).columns
n_cols = 2
n_rows = math.ceil(len(numeric_cols) / n_cols)

plt.figure(figsize=(15, n_rows * 4))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col], kde=True, color='skyblue', edgecolor='black')
    plt.title(f"Distribusi Numerik: {col}")
    plt.xlabel(col)
    plt.ylabel("Frekuensi")

plt.tight_layout()
plt.show()

# %%
# 2. Visualisasi Kolom Kategorikal (object) menggunakan Bar Plot
cat_cols = df.select_dtypes(include=['object']).columns
if len(cat_cols) > 0:
    plt.figure(figsize=(10, 5))
    for col in cat_cols:
        df[col].value_counts().plot(kind='bar', color='salmon', edgecolor='black')
        plt.title(f"Distribusi Kategori: {col}")
        plt.xlabel(col)
        plt.ylabel("Jumlah")
        plt.xticks(rotation=45)
    plt.show()

# %%
# Hitung jumlah tiap kategori
epilepsy_counts = df['species'].value_counts()

# Ambil label otomatis dari data
labels = epilepsy_counts.index

plt.figure(figsize=(7, 7))

plt.pie(
    epilepsy_counts,
    labels=labels,
    autopct='%1.2f%%',
    startangle=90
)

plt.title('Distribution of Species')
plt.show()

# %% [markdown]
# ### 5.1 Cleaning: Menangani Data Kosong dan Duplikat

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
# Menangani Data Kosong

df.dropna(inplace=True)

df.isnull().sum()
# Out:
# sepal_length_cm      0
# sepal_width_cm       0
# petal_length_cm      0
# petal_width_cm       0
# stem_thickness_mm    0
# petal_density_pct    0
# chlorophyll_index    0
# native_altitude_m    0
# species              0
# dtype: int64

# %%
# Menangani Data Duplikat

df.drop_duplicates(inplace=True)

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 5.2 Standarisasi Fitur Numerik

# %%
numerical_cols = df.select_dtypes(include=['number']).columns

# Buat (instantiate) StandardScaler
scaler = StandardScaler()

# Terapkan (fit) scaler ke data dan sekaligus ubah (transform) data tersebut
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Tampilkan 5 baris pertama untuk memverifikasi hasil scaling
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0        -0.911019       -0.552439         0.114654        0.469352
# 1        -0.403240        0.152547        -0.043150        0.020005
# 2        -0.245370       -0.923208         0.160263       -0.314676
# 3         0.150840       -0.769187        -0.279591       -0.661326
# 4        -0.453034       -0.007986        -1.023964       -1.202953
#
#    stem_thickness_mm  petal_density_pct  chlorophyll_index  native_altitude_m  \
# 0          -0.393820           0.745434           0.958796           1.144473
# 1          -0.488398          -0.060039          -1.832424          -1.157353
# 2          -0.200689          -1.234313           1.492775           2.265404
# 3          -0.442197           0.174252          -0.670946           1.338281
# 4          -0.983088           0.505057          -1.048678           0.398890
#
#            species
# 0             Rose
# 1  Iris Versicolor
# 2           Orchid
# ...

# %% [markdown]
# ### 5.3 Penanganan Outlier dengan Metode IQR

# %%
# Melakukan Handling Outlier Data menggunakan metode drop.

for col in numerical_cols:

    # Hitung Kuartil 1 (Q1) dan Kuartil 3 (Q3)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    # Hitung Interquartile Range (IQR)
    IQR = Q3 - Q1

    # Tentukan batas bawah (lower bound) dan batas atas (upper bound)
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter DataFrame: Simpan hanya baris di mana nilai 'df[col]' berada DI ANTARA (inklusif) batas bawah dan batas atas.
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Tampilkan statistik deskriptif setelah outlier dihapus
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# count    154010.000000   154010.000000    154010.000000   154010.000000
# mean         -0.413939       -0.372350        -0.425898       -0.388090
# std           0.411740        0.473990         0.478859        0.614963
# min          -1.886749       -1.720261        -1.460942       -1.951895
# 25%          -0.698621       -0.689801        -0.962871       -1.074156
# 50%          -0.445454       -0.373061        -0.331259       -0.309699
# 75%          -0.154183       -0.062014        -0.068990        0.064569
# max           1.442346        1.114756         1.198681        1.771614
#
#        stem_thickness_mm  petal_density_pct  chlorophyll_index  \
# count      154010.000000      154010.000000      154010.000000
# mean           -0.434763          -0.128481          -0.227450
# std             0.430734           0.969272           0.866235
# min            -1.717469          -2.817252          -2.654969
# ...

# %% [markdown]
# ### 5.4 Encoding Variabel Kategorikal

# %%
# Pilih semua kolom yang bertipe 'object' (kategorikal)
categorical_cols = list(df.select_dtypes(include=['object']).columns)

encoders = {}

# Loop melalui setiap kolom kategorikal
for column in categorical_cols:
    # Buat (instantiate) objek LabelEncoder
    label_encoder = LabelEncoder()

    # Terapkan (fit) encoder ke data dan sekaligus ubah (transform) data tersebut
    df[column] = label_encoder.fit_transform(df[column])

    # Simpan encoder
    encoders[column] = label_encoder

# Tampilkan 5 baris pertama untuk memverifikasi hasil encoding
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0        -0.911019       -0.552439         0.114654        0.469352
# 1        -0.403240        0.152547        -0.043150        0.020005
# 2        -0.245370       -0.923208         0.160263       -0.314676
# 3         0.150840       -0.769187        -0.279591       -0.661326
# 4        -0.453034       -0.007986        -1.023964       -1.202953
#
#    stem_thickness_mm  petal_density_pct  chlorophyll_index  native_altitude_m  \
# 0          -0.393820           0.745434           0.958796           1.144473
# 1          -0.488398          -0.060039          -1.832424          -1.157353
# 2          -0.200689          -1.234313           1.492775           2.265404
# 3          -0.442197           0.174252          -0.670946           1.338281
# 4          -0.983088           0.505057          -1.048678           0.398890
#
#    species
# 0        3
# 1        1
# 2        2
# 3        1
# 4        0

# %% [markdown]
# ### 6. Binning (Pengelompokan Data)
# Di bawah ini adalah contoh pengelompokan fitur `native_altitude_m` menjadi 3 kategori: 'Low', 'Medium', dan 'High'.

# %%
# Contoh implementasi Binning pada kolom native_altitude_m
# Karena data sudah di-scaling (StandardScaler), kita gunakan 3 group secara proporsional

df['altitude_group'] = pd.qcut(df['native_altitude_m'], q=3, labels=['Low', 'Medium', 'High'])

# Tampilkan hasil binning
display(df[['native_altitude_m', 'altitude_group']].head(10))

# Visualisasi hasil binning
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='altitude_group', hue='species', palette='viridis')
plt.title('Distribusi Spesies berdasarkan Kelompok Ketinggian')
plt.show()
# Out:
#     native_altitude_m altitude_group
# 0            1.144473           High
# 1           -1.157353            Low
# 2            2.265404           High
# 3            1.338281           High
# 4            0.398890         Medium
# 5            0.279963         Medium
# 6            2.018041           High
# 8            0.244600         Medium
# 9           -0.746427            Low
# 10          -1.341503            Low
